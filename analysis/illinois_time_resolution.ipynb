# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import pygenesys as pg
from plotter import *
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,12)

# %%
def get_objective(conn):
    """
    Retrieves the objective function
    """
    cursor = conn.cursor()
    command = "SELECT * FROM Output_Objective"
    cursor.execute(command)
    obj_value = cursor.fetchall()[0][-1]
    
    return obj_value

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CC30_4.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

# plot_electricity_profiles(conn,'IL','ELC')
cap_df_4 = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df_4/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df_4 = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df_4).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()

# %%
tot_gwh = 1262250.0
get_objective(conn)/tot_gwh*1000
# Out:
# 95.69618438575641

# %%
cap_df_4/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_CONV  SOLAR_FARM  WIND_FARM
# year
# 2025    7.50590    0.128100     16.37160       12.4151    0.152200   6.294820
# 2030    5.04524   14.468378     16.33270       12.4200   20.639874  22.946609
# 2035    2.81574   15.574992     15.90398       12.4200   22.863527  25.168937
# 2040    2.44440   16.677664      5.02332       12.4200   25.160870  27.363973
# 2045    2.35704   17.780336      0.68880       12.4200   27.458213  29.559009
# 2050    2.25560   18.883008      0.68880       12.4200   29.755556  31.754045

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CC30_12.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

# plot_electricity_profiles(conn,'IL','ELC')
cap_df_12 = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df_12/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df_12 = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df_12).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()

# %%
tot_gwh = 1262250.0
get_objective(conn)/tot_gwh*1000
# Out:
# 99.79998685636137

# %%
cap_df_12/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_ADV  NUCLEAR_CONV  \
# year
# 2025    7.50590    0.357410     16.37160     0.000000         12.42
# 2030    5.04524    9.173765     16.33270     7.807022         12.42
# 2035    2.81574    9.884574     15.90398     8.478058         12.42
# 2040    2.44440   11.364682      5.02332     8.478058         12.42
# 2045    2.35704   12.882987      0.68880     8.478058         12.42
# 2050    2.25560   14.520333      0.68880     8.478058         12.42
#
#       SOLAR_FARM  WIND_FARM
# year
# 2025    0.152200   6.294820
# 2030   12.654336   5.615460
# 2035   14.145717   6.318523
# 2040   17.580575   8.040970
# 2045   20.960143   9.804764
# 2050   24.278872  11.609298

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CC30_52.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

# plot_electricity_profiles(conn,'IL','ELC')
cap_df_52 = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df_52/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df_52 = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df_52).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()

# %%
tot_gwh = 1262250.0
get_objective(conn)/tot_gwh*1000
# Out:
# 101.38749061794731

# %%
cap_df_52/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_ADV  NUCLEAR_CONV  \
# year
# 2025    7.50590    0.791104     16.37160     0.000000         12.42
# 2030    5.04524    8.686661     16.33270     8.215785         12.42
# 2035    2.81574    9.004930     15.90398     9.430019         12.42
# 2040    2.44440    9.274146      5.02332    10.589531         12.42
# 2045    2.35704    9.823560      0.68880    11.416384         12.42
# 2050    2.25560   11.200449      0.68880    11.438562         12.42
#
#       SOLAR_FARM  WIND_FARM
# year
# 2025    0.152200   6.294820
# 2030   13.475155   5.615460
# 2035   13.454335   4.998179
# 2040   13.436395   4.969035
# 2045   14.677456   5.452559
# 2050   18.864328   7.214300

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CC30_365_LC.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

# plot_electricity_profiles(conn,'IL','ELC')
cap_df_365 = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df_365/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df_365 = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df_365).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()

# %%
tot_gwh = 1262250.0
get_objective(conn)/tot_gwh*1000
# Out:
# 128.40839668029398

# %%
cap_df_365/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_ADV  NUCLEAR_CONV  \
# year
# 2025    7.50590    9.317813     16.37160     0.000000         12.42
# 2030    5.04524   11.773787     16.33270    12.973058         12.42
# 2035    2.81574   13.589450     15.90398    14.160821         12.42
# 2040    2.44440   15.053997      5.02332    14.801370         12.42
# 2045    2.35704   16.327038      0.68880    15.744616         12.42
# 2050    2.25560   17.007331      0.68880    16.918142         12.42
#
#       SOLAR_FARM  WIND_FARM
# year
# 2025    6.471514   6.387820
# 2030   15.513517   5.708460
# 2035   17.606866   3.303620
# 2040   23.597089   2.044242
# 2045   26.505467   1.692012
# 2050   27.609861   1.762513

# %%
# plot_electricity_profiles(conn,'IL','ELC')

# %%
ofv = 89033e6
cc30_ofv = 130271e6  # dollars
demand = 1267698.8
# demand = 6338493.91422408
cc30_ofv / demand / 1e6 # dollars per kWh
# Out:
# 0.10276179168111542

# %%
175e3/1267698.8
# Out:
# 0.13804540952472305

# %%
proportion = lambda x: x*100/sum(x)

# %%
stacked_cap_4 = cap_df_4.apply(proportion, axis=1)
stacked_cap_12 = cap_df_12.apply(proportion, axis=1)
stacked_cap_52 = cap_df_52.apply(proportion, axis=1)
stacked_cap_365 = cap_df_365.apply(proportion, axis=1)

# %%
stacked_gen_4 = gen_df_4.apply(proportion, axis=1)
stacked_gen_12 = gen_df_12.apply(proportion, axis=1)
stacked_gen_52 = gen_df_52.apply(proportion, axis=1)
stacked_gen_365 = gen_df_365.apply(proportion, axis=1)

# %%
fig, ax = plt.subplots(figsize=(12,9))
w=0.1

(stacked_cap_4).plot.bar(ax=ax, stacked=True, 
                         color=elc_colors, width=w, 
                         position=1.2, align='center',
                         legend=True,edgecolor='gray').legend(loc='upper center', ncol=6, title="Technologies")
(stacked_cap_12).plot.bar(ax=ax, stacked=True, 
                          color=elc_colors, width=w, 
                          position=0, align='center',
                          legend=False,edgecolor='gray')
(stacked_cap_52).plot(ax=ax, kind='bar', stacked=True, 
                      color=elc_colors, width=w, 
                      position=-1.2, align='center',
                      legend=False, edgecolor='gray')
ax.set_ylabel("Installed Capacity [%]", fontsize=20)
ax.grid(zorder=0)
# ax.grid(which='major')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
mpl.use("pgf")
plt.rcParams['pgf.texsystem'] = 'pdflatex'
plt.rcParams['pgf.rcfonts'] = False
plt.rcParams['figure.edgecolor'] = 'k'
plt.rcParams['figure.facecolor'] = 'w'
plt.rcParams['savefig.dpi'] = 400
plt.rcParams['savefig.bbox'] = 'tight'
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = "serif"

# %%
fig, ax = plt.subplots(figsize=(12,9))
w=0.15

(cap_df_4/1000).plot.bar(ax=ax, stacked=True, 
                         color=elc_colors, width=w, 
                         position=0.0, align='center',
                         legend=True,edgecolor='gray')
(cap_df_12/1000).plot.bar(ax=ax, stacked=True, 
                          color=elc_colors, width=w, 
                          position=-1.1, align='center',
                          legend=False,edgecolor='gray')
(cap_df_52/1000).plot(ax=ax, kind='bar', stacked=True, 
                      color=elc_colors, width=w, 
                      position=-2.2, align='center',
                      legend=False, edgecolor='gray')
(cap_df_365/1000).plot(ax=ax, kind='bar', stacked=True, 
                      color=elc_colors, width=w, 
                      position=-3.3, align='center',
                      legend=False, edgecolor='gray')
plt.show()
# Out:
# <ipython-input-23-a62c4f34ef19>:20: UserWarning: Matplotlib is currently using pgf, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
fig, axes = plt.subplots(2,2, figsize=(20,20), sharex=True)

w=0.15

# Capacity

(cap_df_4/1000).plot.bar(ax=axes[0,0], stacked=True, 
                         color=elc_colors, width=w, 
                         position=0.0, align='center',
                         legend=False,edgecolor='gray')
(cap_df_12/1000).plot.bar(ax=axes[0,0], stacked=True, 
                          color=elc_colors, width=w, 
                          position=-1.1, align='center',
                          legend=False,edgecolor='gray')
(cap_df_52/1000).plot(ax=axes[0,0], kind='bar', stacked=True, 
                      color=elc_colors, width=w, 
                      position=-2.2, align='center',
                      legend=False, edgecolor='gray')
(cap_df_365/1000).plot(ax=axes[0,0], kind='bar', stacked=True, 
                      color=elc_colors, width=w, 
                      position=-3.3, align='center',
                      legend=False, edgecolor='gray')


# Generation
(gen_df_4/1000).plot.bar(ax=axes[0,1], stacked=True, 
                         color=elc_colors, width=w, 
                         position=0.0, align='center',
                         legend=False,edgecolor='gray')
(gen_df_12/1000).plot.bar(ax=axes[0,1], stacked=True, 
                          color=elc_colors, width=w, 
                          position=-1.1, align='center',
                          legend=False,edgecolor='gray')
(gen_df_52/1000).plot(ax=axes[0,1], kind='bar', stacked=True, 
                      color=elc_colors, width=w, 
                      position=-2.2, align='center',
                      legend=False, edgecolor='gray')
(gen_df_365/1000).plot(ax=axes[0,1], kind='bar', stacked=True, 
                      color=elc_colors, width=w, 
                      position=-3.3, align='center',
                      legend=False, edgecolor='gray')


(stacked_cap_4).plot.bar(ax=axes[1,0], stacked=True, 
                         color=elc_colors, width=w, 
                         position=0.0, align='center',
                         legend=False,edgecolor='gray')
(stacked_cap_12).plot.bar(ax=axes[1,0], stacked=True, 
                          color=elc_colors, width=w, 
                          position=-1.1, align='center',
                          legend=False,edgecolor='gray')
(stacked_cap_52).plot(ax=axes[1,0], kind='bar', stacked=True, 
                      color=elc_colors, width=w, 
                      position=-2.2, align='center',
                      legend=False, edgecolor='gray')
(stacked_cap_365).plot(ax=axes[1,0], kind='bar', stacked=True, 
                      color=elc_colors, width=w, 
                      position=-3.3, align='center',
                      legend=False, edgecolor='gray')


(stacked_gen_4).plot.bar(ax=axes[1,1], stacked=True, 
                         color=elc_colors, width=w, 
                         position=0.0, align='center',
                         legend=False,edgecolor='gray')
(stacked_gen_12).plot.bar(ax=axes[1,1], stacked=True, 
                          color=elc_colors, width=w, 
                          position=-1.1, align='center',
                          legend=False,edgecolor='gray')
(stacked_gen_52).plot(ax=axes[1,1], kind='bar', stacked=True, 
                      color=elc_colors, width=w, 
                      position=-2.2, align='center',
                      legend=False, edgecolor='gray')
(stacked_gen_365).plot(ax=axes[1,1], kind='bar', stacked=True, 
                      color=elc_colors, width=w, 
                      position=-3.3, align='center',
                      legend=False, edgecolor='gray')

axes[0,0].set_ylabel("[GW]", fontsize=24)
axes[0,1].set_ylabel("[TWh]", fontsize=24)
axes[1,0].set_ylabel("[%]", fontsize=24)
axes[1,1].set_ylabel("[%]", fontsize=24)
# axes[1].set_ylabel("Installed Capacity [%]", fontsize=20)


axes[1,0].set_xlabel("Year", fontsize=24)
axes[1,1].set_xlabel("Year", fontsize=24)
axes[1,0].tick_params(axis='x', labelsize=20, rotation=0, pad=10)
axes[1,1].tick_params(axis='x', labelsize=20, rotation=0, pad=10)

axes[0,0].tick_params(axis='y', labelsize=20)
axes[0,1].tick_params(axis='y', labelsize=20)
axes[1,0].tick_params(axis='y', labelsize=20)
axes[1,1].tick_params(axis='y', labelsize=20)

axes[0,0].set_title("Installed Capacity", fontsize=24)
axes[0,1].set_title("Total Generation", fontsize=24)

handles, labels = axes[0,1].get_legend_handles_labels()
by_label = dict(zip(labels, handles))
legend = plt.figlegend(by_label.values(), by_label.keys(), bbox_to_anchor=(0.85,0.01), ncol=4, 
              fontsize=20, shadow=True, title='Technologies')
plt.suptitle('Illinois: 2030 Net Zero Electricity at 4 Time Resolutions \n Scenario: Least Cost\n', fontsize=36)
plt.setp(legend.get_title(),fontsize=24)
plt.tight_layout()
plt.savefig('../thesis/figures/time_resolution_plot_LC.pgf')

# %%
((cap_df_4-cap_df_365)/cap_df_365*100)[cap_df_4.index==2050]
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_ADV  NUCLEAR_CONV  \
# year
# 2050        0.0   11.028638          0.0          NaN           0.0
#
#       SOLAR_FARM    WIND_FARM
# year
# 2050    7.771481  1701.634859

# %%
((cap_df_12-cap_df_365)/cap_df_365*100)[cap_df_12.index==2050]
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_ADV  NUCLEAR_CONV  \
# year
# 2050        0.0  -14.623094          0.0   -49.887774           0.0
#
#       SOLAR_FARM   WIND_FARM
# year
# 2050   -12.06449  558.678791

# %%
((cap_df_52-cap_df_365)/cap_df_365*100)[cap_df_52.index==2050]
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_ADV  NUCLEAR_CONV  \
# year
# 2050        0.0  -34.143406          0.0   -32.388781           0.0
#
#       SOLAR_FARM  WIND_FARM
# year
# 2050  -31.675397  309.31899

# %%
dem = gen_df_52[gen_df_52.index==2030].sum().sum()

# %%
dem
# Out:
# 204744.61290820857

# %%
sol_gen = gen_df_52.SOLAR_FARM[gen_df_52.index==2030]
wnd_gen = gen_df_52.WIND_FARM[gen_df_52.index==2030]

# %%
(sol_gen+wnd_gen)/dem
# Out:
# year
# 2030    0.184538
# dtype: float64
