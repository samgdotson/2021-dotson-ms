# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import pygenesys as pg
from plotter import *
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,12)

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_BAU_PJM_4.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:265: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
cap_df/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_CONV  SOLAR_FARM  WIND_FARM
# year
# 2025    7.50590    0.064560    16.371600      12.41510     0.15220    6.29482
# 2030    5.04524    0.740025    24.857326       9.38720     0.15040    5.61546
# 2035    2.81574    4.803361    24.428606       8.37790     0.12958    3.21062
# 2040    2.44440    4.915042    28.105930       7.90990     0.11164    1.91224
# 2045    2.35704    4.825035    40.579684       2.41516     0.00640    0.00000
# 2050    2.25560    5.025649    46.722885       0.00000     0.00000    0.00000

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_BAU_PJM_12.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:265: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
cap_df/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_CONV  SOLAR_FARM  WIND_FARM
# year
# 2025    7.50590    0.064560    16.912341      12.41510     0.15220    6.29482
# 2030    5.04524    0.698526    25.778480       9.38720     0.15040    5.61546
# 2035    2.81574    4.646613    25.349760       8.37790     0.12958    3.21062
# 2040    2.44440    4.812813    28.821938       7.90990     0.11164    1.91224
# 2045    2.35704    4.935163    40.746962       2.41516     0.00640    0.00000
# 2050    2.25560    5.139817    46.898195       0.00000     0.00000    0.00000

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_BAU_PJM_52.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:265: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
cap_df/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_CONV  SOLAR_FARM  WIND_FARM
# year
# 2025    7.50590    0.064560    17.700875      12.41510     0.15220    6.29482
# 2030    5.04524    1.021837    26.015960       9.38720     0.15040    5.61546
# 2035    2.81574    4.987642    25.587240       8.37790     0.12958    3.21062
# 2040    2.44440    5.221777    28.971101       7.90990     0.11164    1.91224
# 2045    2.35704    5.412225    40.806359       2.41516     0.00640    0.00000
# 2050    2.25560    5.636926    46.959798       0.00000     0.00000    0.00000

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CAP30_PJM_4.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:265: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
cap_df/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_CONV  SOLAR_FARM  WIND_FARM
# year
# 2025    7.50590    0.064560     16.37160      12.41510    0.152200   6.294820
# 2030    5.04524   13.336313     16.33270       9.38720   44.231100  20.963478
# 2035    2.81574   14.908407     15.90398       8.37790   49.563626  24.514351
# 2040    2.44440   18.031764      5.02332       7.90990   58.732298  24.909278
# 2045    2.35704   30.279490      0.68880       2.41516   94.533593  27.539983
# 2050    2.25560   38.088090      0.68880       0.00000  117.036170  27.539983

# %% [markdown]
# command = """
#           SELECT * FROM Output_Curtailment
#           WHERE tech is 'SOLAR_FARM'
#           ORDER BY Output_Curtailment.t_periods
#           """
# cursor = conn.cursor()
# data = cursor.execute(command)
# print(data.description)
# d = cursor.fetchall()
# for i in d:
#     print(i)

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CAP30_PJM_12.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:265: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
cap_df/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_CONV  SOLAR_FARM  WIND_FARM
# year
# 2025    7.50590    0.361967     16.37160      12.41510    0.152200   6.294820
# 2030    5.04524   14.580384     16.33270       9.38720   49.733147  21.269047
# 2035    2.81574   16.406610     15.90398       8.37790   57.954221  24.292877
# 2040    2.44440   17.935597      5.02332       7.90990   63.647275  26.620244
# 2045    2.35704   24.996031      0.68880       2.41516   86.263894  36.090457
# 2050    2.25560   28.739320      0.68880       0.00000   98.303098  41.206425

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CAP30_PJM_52.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:265: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
cap_df/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_CONV  SOLAR_FARM  WIND_FARM
# year
# 2025    7.50590    0.795661     16.37160      12.41510    0.152200   6.294820
# 2030    5.04524   16.509612     16.33270       9.38720   52.882642  23.962891
# 2035    2.81574   19.124158     15.90398       8.37790   60.653753  27.368771
# 2040    2.44440   20.656736      5.02332       7.90990   69.468514  28.564338
# 2045    2.35704   28.691317      0.68880       2.41516   94.568643  38.703767
# 2050    2.25560   32.960906      0.68880       0.00000  108.093350  44.141375

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CAP50_PJM_4.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:265: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
cap_df/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_ADV  NATGAS_CONV  NUCLEAR_CONV  \
# year
# 2025    7.50590    0.064560    0.000000    16.371600      12.41510
# 2030    5.04524    1.333113    0.000000    23.778984       9.38720
# 2035    2.81574    4.803361    0.000000    24.428606       8.37790
# 2040    2.44440    4.003493    7.701479    22.061813       7.90990
# 2045    2.35704    1.388099   27.307271    17.727293       2.41516
# 2050    2.25560   38.088090   27.307271    17.727293       0.00000
#
#       SOLAR_FARM  WIND_FARM
# year
# 2025     0.15220   6.294820
# 2030     0.15040   5.615460
# 2035     0.12958   3.210620
# 2040     0.11164   1.912240
# 2045    18.14816   0.000000
# 2050   117.03617  27.539983

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CAP50_PJM_12.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:265: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
cap_df/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_ADV  NATGAS_CONV  NUCLEAR_CONV  \
# year
# 2025    7.50590    0.064560    0.000000    16.912341      12.41510
# 2030    5.04524    0.698526    0.000000    25.778480       9.38720
# 2035    2.81574    4.646613    0.000000    25.349760       8.37790
# 2040    2.44440    4.315339    7.759091    21.967345       7.90990
# 2045    2.35704    1.667076   27.142720    17.632825       2.41516
# 2050    2.25560   28.739320   27.142720    17.632825       0.00000
#
#       SOLAR_FARM  WIND_FARM
# year
# 2025    0.152200   6.294820
# 2030    0.150400   5.615460
# 2035    0.129580   3.210620
# 2040    0.111640   1.912240
# 2045   18.791822   0.000000
# 2050   98.303098  41.206425

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CAP50_PJM_52.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:265: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
cap_df/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_ADV  NATGAS_CONV  NUCLEAR_CONV  \
# year
# 2025    7.50590    0.064560    0.000000    17.700875      12.41510
# 2030    5.04524    1.021837    0.000000    26.015960       9.38720
# 2035    2.81574    4.987642    0.000000    25.587240       8.37790
# 2040    2.44440    4.614574    7.519075    22.556031       7.90990
# 2045    2.35704    1.826356   27.318194    18.221511       2.41516
# 2050    2.25560   32.960906   27.318194    18.221511       0.00000
#
#       SOLAR_FARM  WIND_FARM
# year
# 2025    0.152200   6.294820
# 2030    0.150400   5.615460
# 2035    0.129580   3.210620
# 2040    0.111640   1.912240
# 2045   18.156719   0.000000
# 2050  108.093350  44.141375
