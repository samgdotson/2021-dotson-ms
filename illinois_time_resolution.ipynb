# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import pygenesys as pg
from plotter import *
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,12)

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_BAU_4.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:265: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CC50_4.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:265: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CC30_4.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:266: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
cap_df/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_CONV  SOLAR_FARM  WIND_FARM
# year
# 2025    7.50590    0.128100     16.37160       12.4151    0.152200   6.294820
# 2030    5.04524   14.468378     16.33270       12.4200   20.639874  22.946609
# 2035    2.81574   15.574992     15.90398       12.4200   22.863527  25.168937
# 2040    2.44440   16.677664      5.02332       12.4200   25.160870  27.363973
# 2045    2.35704   17.780336      0.68880       12.4200   27.458213  29.559009
# 2050    2.25560   18.883008      0.68880       12.4200   29.755556  31.754045

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_BAU_12.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-5-447e8bb6b3da> in <module>
#       3 cursor = conn.cursor()
#       4
# ----> 5 plot_electricity_profiles(conn,'IL','ELC')
#       6 cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
#       7 (cap_df/1000).plot(kind='bar', stacked=True, color=elc_colors)
#
# ~/research/2021-dotson-ms/plotter.py in plot_electricity_profiles(db_conn, region, outcomm, colors, N_hours)
#     242     """
#     243
# --> 244     seasons = get_seasons(db_conn)
#     245     periods = get_periods(db_conn)
#     246     all_techs = get_regional_techs(db_conn, outcomm, region)
#
# ~/research/2021-dotson-ms/plotter.py in get_seasons(db_conn)
#     113
#     114     cur = db_conn.cursor()
# --> 115     cur.execute(command)
#     116     seasons = [s[0] for s in cur.fetchall()]
#     117
#
# OperationalError: no such table: time_season

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CC50_12.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CC30_12.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:266: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
cap_df/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_ADV  NUCLEAR_CONV  \
# year
# 2025    7.50590    0.357410     16.37160     0.000000         12.42
# 2030    5.04524    9.173765     16.33270     7.807022         12.42
# 2035    2.81574    9.884574     15.90398     8.478058         12.42
# 2040    2.44440   11.364682      5.02332     8.478058         12.42
# 2045    2.35704   12.882987      0.68880     8.478058         12.42
# 2050    2.25560   14.520333      0.68880     8.478058         12.42
#
#       SOLAR_FARM  WIND_FARM
# year
# 2025    0.152200   6.294820
# 2030   12.654336   5.615460
# 2035   14.145717   6.318523
# 2040   17.580575   8.040970
# 2045   20.960143   9.804764
# 2050   24.278872  11.609298

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_BAU_52.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CC50_52.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/data_files/IL_CC30_52.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:266: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
cap_df/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_ADV  NUCLEAR_CONV  \
# year
# 2025    7.50590    0.791104     16.37160     0.000000         12.42
# 2030    5.04524    8.686661     16.33270     8.215785         12.42
# 2035    2.81574    9.004930     15.90398     9.430019         12.42
# 2040    2.44440    9.274146      5.02332    10.589531         12.42
# 2045    2.35704    9.823560      0.68880    11.416384         12.42
# 2050    2.25560   11.200449      0.68880    11.438562         12.42
#
#       SOLAR_FARM  WIND_FARM
# year
# 2025    0.152200   6.294820
# 2030   13.475155   5.615460
# 2035   13.454335   4.998179
# 2040   13.436395   4.969035
# 2045   14.677456   5.452559
# 2050   18.864328   7.214300

# %%
ofv = 89033e6
cc30_ofv = 130271e6  # dollars
demand = 1267698.8
# demand = 6338493.91422408
cc30_ofv / demand / 1e6 # dollars per kWh
# Out:
# 0.10276179168111542
