# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import pygenesys as pg
from plotter import *
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,12)

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/zero_nuclear/IL_ZN_CC30_4.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:266: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
cap_df/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_CONV  SOLAR_FARM  WIND_FARM
# year
# 2025    7.50590    0.128100     16.37160      12.41510    0.152200   6.294820
# 2030    5.04524   16.478474     16.33270       9.38720   26.632963  29.195300
# 2035    2.81574   18.093260     15.90398       8.37790   30.008061  34.243548
# 2040    2.44440   19.414486      5.02332       7.90990   32.592105  37.932408
# 2045    2.35704   23.936141      0.68880       2.41516   42.363917  54.187646
# 2050    2.25560   26.562083      0.68880       0.00000   47.781351  62.692955

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/zero_nuclear/IL_ZN_CC30_12.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:266: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
cap_df/1000
# Out:
#       COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_CONV  SOLAR_FARM  WIND_FARM
# year
# 2025    7.50590    0.361967     16.37160      12.41510    0.152200   6.294820
# 2030    5.04524   28.513164     16.33270       9.38720   44.353393  22.267708
# 2035    2.81574   32.926793     15.90398       8.37790   50.840288  25.512632
# 2040    2.44440   36.204581      5.02332       7.90990   55.701090  27.945571
# 2045    2.35704   50.029694      0.68880       2.41516   75.661376  37.920161
# 2050    2.25560   57.392948      0.68880       0.00000   86.370834  43.274754

# %%
elc_colors
# Out:
# {'ELC_EX': 'tab:brown',
#  'IMP_ELC': 'tab:brown',
#  'BIOMASS': 'tab:brown',
#  'ABBOTT_TB': 'tab:red',
#  'ABBOTT': 'tab:red',
#  'NUCLEAR_THM': 'tab:green',
#  'NUCLEAR_TB': 'tab:green',
#  'LI_BATTERY': 'dimgray',
#  'SOLAR_FARM': 'yellow',
#  'WIND_FARM': 'tab:blue',
#  'COAL_CONV': 'k',
#  'COAL_ADV': 'firebrick',
#  'NATGAS_ADV': 'tab:orange',
#  'NATGAS_CONV': 'tan',
#  'NUCLEAR_ADV': 'tab:green',
#  'NUCLEAR_CONV': 'lightblue',
#  'CWS': 'tab:purple',
#  'CW_STORAGE': 'tab:pink'}

# %%
sim_path = "/home/sdotson/research/2021-dotson-ms/simulations/illinois/zero_nuclear/IL_ZN_CC30_52.sqlite"
conn = sqlite3.connect(sim_path)
cursor = conn.cursor()

plot_electricity_profiles(conn,'IL','ELC')
cap_df = get_annual_capacity(conn, 'IL', 'ELC' )
(cap_df/1000).plot(kind='bar', stacked=True, color=elc_colors)
plt.title('Capacity Plot for Scenario: Business As Usual')
plt.ylabel('Capacity [GW]')
plt.minorticks_on()
plt.show()
gen_df = get_annual_generation(conn, 'IL', 'ELC' )
(gen_df).plot(kind='bar', stacked=True, color=elc_colors)
plt.ylabel('Generation [GWh]')
plt.minorticks_on()
plt.show()
# Out:
# /home/sdotson/research/2021-dotson-ms/plotter.py:266: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes, labels=techs, loc='right',bbox_to_anchor=(1.3, 0.75), fontsize=21)

# %%
cap_df/1000
# Out:
#        BIOMASS  COAL_CONV  LI_BATTERY  NATGAS_CONV  NUCLEAR_CONV  SOLAR_FARM  \
# year
# 2025  0.000000    7.50590    0.795661     16.37160      12.41510    0.152200
# 2030  2.359007    5.04524   28.834851     16.33270       9.38720   46.897832
# 2035  2.359007    2.81574   33.849177     15.90398       8.37790   54.554791
# 2040  2.359007    2.44440   37.643531      5.02332       7.90990   60.298608
# 2045  2.413811    2.35704   53.669974      0.68880       2.41516   83.928420
# 2050  2.540657    2.25560   62.005340      0.68880       0.00000   96.356471
#
#       WIND_FARM
# year
# 2025   6.294820
# 2030  20.674361
# 2035  24.031768
# 2040  26.541548
# 2045  36.761229
# 2050  42.226306

# %%
ofv = 89033e6
cc30_ofv = 174271e6
demand = 1267698.8
cc30_ofv / demand / 1e6 # dollars per kWh
# Out:
# 0.13747035179018863
