# %%
import pandas as pd
# Keeping pandas from truncating long strings
pd.set_option('display.max_colwidth', None)

# %%
rev_df = pd.read_csv('esom_lit_review.csv', usecols=['Author','Timeslices', 'Horizon', 'Place', 'Modeling Tool', 'Notes'])
rev_df
# Out:
#                                Author Timeslices          Horizon  \
# 0   Alzbutas, R. & Norvaisa, E., 2012         NS    (2010,2025,5)
# 1                   Baker et al. 2016       8760              NaN
# 2         Barron R. & McJeon H., 2016         NS    (2020,2095,5)
# 3                 Bennett et al. 2021         48    (2015,2040,5)
# 4               Bouckaert et al. 2014         16    (2010,2030,5)
# 5              de Queiroz et al. 2019   Variable  One month ahead
# 6            de Sisternes et al. 2016        672              NaN
# 7               DeCarolis et al. 2016          4    (2015,2050,5)
# 8                  Epiney et al. 2020       8760      Single year
# 9                  Garcia et al. 2016       8760      Single year
# 10                 Kotzur et al. 2017   Variable              NaN
# 11               Komiyama et al. 2015      52560      Single year
# 12                     Li et al. 2019         96    (2015,2050,5)
# ...

# %%
rev_df.to_latex('2021-dotson-ms/thesis/tables/esom_lit_review.tex', index=False)
